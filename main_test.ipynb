# %%
import pandas as pd
from Project.student_data_gen import student_gen
import transform as tc

def main():
    studentdf = student_gen()
    outdf = tc.transform(studentdf)
    print(outdf)
    return outdf

# %%
main()
# Out:
#    StudentID       Name  Age      Grade        Department
# 0          1   Student1   24  72.999247              Math
# 1          2   Student2   21  83.777467           Physics
# 2          3   Student3   22  80.011258         Chemistry
# 3          4   Student4   24  74.286005           Biology
# 4          5   Student5   20  89.526654           History
# 5          6   Student6   22  71.692347  Computer Science
# 6          7   Student7   22  91.659963           English
# 7          8   Student8   24  98.156581         Geography
# 8          9   Student9   19  70.023363         Economics
# 9         10  Student10   20  99.766347               Art
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 main()
#
# Cell In[8], line 7, in main()
#       5 def main():
#       6     studentdf = student_gen()
# ----> 7     outdf = tc.transform(studentdf)
# ...
